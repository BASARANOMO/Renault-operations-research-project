# %%
using PyPlot: pygui
pygui(true)
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
include("import_all.jl")
# Out:
# ┌ Info: Running `conda install -y -c conda-forge folium` in root environment
# └ @ Conda C:\Users\BASARA\.julia\packages\Conda\x5ml4\src\Conda.jl:115
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\BASARA\.julia\conda\3
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.12.5          |   py38haa244fe_1         144 KB  conda-forge
#     folium-0.12.0              |     pyhd8ed1ab_0          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         207 KB
#
# The following packages will be UPDATED:
#
#   certifi                          2020.12.5-py38haa244fe_0 --> 2020.12.5-py38haa244fe_1
#   folium                                        0.11.0-py_0 --> 0.12.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# folium-0.12.0        | 64 KB     | ########## | 100%
# certifi-2020.12.5    | 144 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# write_solution_to_file (generic function with 1 method)

# %%
instance_europe = lire_instance(joinpath("..", "sujet", "europe.csv"))
# Out:
# Reading graph 100%|█████████████████████████████████████| Time: 0:00:01
# Instance
#    Nombre de jours: 21
#    Nombre d'usines: 25
#    Nombre de fournisseurs: 576
#    Nombre de types d'emballages: 27
#    Nombre de routes: 0

# %%
instance_europe_solved = lire_solution(instance_europe, joinpath("..", "sujet", "europe best 5.txt"))
# Out:
# Instance
#    Nombre de jours: 21
#    Nombre d'usines: 25
#    Nombre de fournisseurs: 576
#    Nombre de types d'emballages: 27
#    Nombre de routes: 3239

# %%
feasibility(instance_europe_solved)
# Out:
# true

# %%
cost(instance_europe_solved)
# Out:
# 6682930

# %%
instance_europe_greedy = lire_solution(instance_europe, joinpath("sol_europe.txt"))
# Out:
# Instance
#    Nombre de jours: 21
#    Nombre d'usines: 25
#    Nombre de fournisseurs: 576
#    Nombre de types d'emballages: 27
#    Nombre de routes: 3239

# %%
feasibility(instance_europe_greedy)
# Out:
# true

# %%
cost(instance_europe_greedy)
# Out:
# 8289246

# %%
plot_routes(instance_europe_greedy, j=1)
